# %% [markdown]
# # 226. Invert Binary Tree
# **Category:** Trees / Structural Transformations
# **Difficulty:** Easy
#
# Given the root of a binary tree, invert the tree and return its root.
#
# Inversion means swapping the left and right children of every node.
#
# ### Example
#
# Input:
#     4
#    / \
#   2   7
#  / \ / \
# 1  3 6  9
#
# Output:
#     4
#    / \
#   7   2
#  / \ / \
# 9  6 3  1

# %% [markdown]
# # 🎯 Intuition & ML Relevance
#
# This problem is the “Hello World” of tree manipulation.
#
# It demonstrates:
#
# - Recursive structural transformations
# - Understanding of tree symmetry
# - Depth-first traversal
# - Clean, elegant recursion
#
# ML relevance:
#
# - Tree transformations (decision trees, ASTs, parse trees)
# - Data augmentation for tree‑structured data
# - Structural reasoning in hierarchical models
# - Graph transformations
#
# The key idea:
#
# > Swap the left and right children at every node.

# %% [markdown]
# # 🟦 Recursive DFS Solution

# %%
def invertTree(root):
    if not root:
        return None

    # Swap children
    root.left, root.right = root.right, root.left

    # Recurse on children
    invertTree(root.left)
    invertTree(root.right)

    return root

# %% [markdown]
# # ⚙️ Recursive Explanation
#
# At each node:
#
# 1. Swap the left and right children
# 2. Recursively invert the left subtree
# 3. Recursively invert the right subtree
#
# This is a classic DFS pattern.
#
# The recursion naturally handles:
#
# - Leaf nodes
# - Null children
# - Arbitrary tree shapes

# %% [markdown]
# # 🟦 Iterative BFS Version

# %%
from collections import deque

def invertTree_bfs(root):
    if not root:
        return None

    queue = deque([root])

    while queue:
        node = queue.popleft()

        # Swap children
        node.left, node.right = node.right, node.left

        if node.left:
            queue.append(node.left)
        if node.right:
            queue.append(node.right)

    return root

# %% [markdown]
# # ⏱️ Time & Space Complexity
#
# ### Time Complexity: **O(n)**
# We visit each node once.
#
# ### Space Complexity:
# - **O(h)** for recursion (h = tree height)
# - **O(n)** worst case for BFS queue
#
# Both are optimal for tree traversal.

# %% [markdown]
# # ⚠️ Edge Cases
#
# - Empty tree → return None
# - Single node → unchanged
# - Unbalanced trees → recursion still works
# - Very deep trees → BFS version avoids recursion depth issues

# %% [markdown]
# # 🧠 Reflection
#
# This problem strengthened my understanding of:
#
# - Tree traversal patterns
# - Structural transformations
# - Recursion fundamentals
# - BFS vs DFS tradeoffs
#
# It’s a foundational tree problem and a perfect warm‑up for more complex structural reasoning tasks like:
#
# - Symmetric Tree
# - Path Sum
# - Lowest Common Ancestor
# - Validate BST
